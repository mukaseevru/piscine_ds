# %% [markdown]
# ## Imports

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# ## make a connection to the database (it is the same as the previous day)

# %%
connect = sqlite3.connect('../data/checking-logs.sqlite.sqlite')

# %% [markdown]
# ## run a query that gets the datetime from the pageviews table, selecting only the users and not the admins

# %%
request = '''
SELECT *
FROM pageviews
WHERE uid LIKE 'user_%'
'''
df = pd.io.sql.read_sql(request, connect, parse_dates=['datetime'])
df
# Out:
#      index      uid                   datetime
# 0       12  user_30 2020-04-17 22:46:26.785035
# 1       14  user_14 2020-04-18 10:53:52.623447
# 2       15  user_17 2020-04-18 10:56:55.833899
# 3       16  user_14 2020-04-18 10:57:37.331258
# 4       18  user_17 2020-04-18 12:05:48.200144
# ..     ...      ...                        ...
# 982   1073  user_28 2020-05-21 18:45:20.441142
# 983   1074  user_19 2020-05-21 23:03:06.457819
# 984   1075  user_25 2020-05-21 23:23:49.995349
# 985   1078   user_5 2020-05-22 11:30:18.368990
# 986   1079  user_17 2020-05-22 18:22:22.847815
#
# [987 rows x 3 columns]

# %% [markdown]
# ## using Pandas, create a new dataframe where the visits are counted and grouped by date

# %%
new_df = df.groupby(by=df['datetime'].dt.date).count()['uid'].reset_index()
new_df.columns = ['date', 'views']
new_df = new_df.set_index('date')
new_df
# Out:
#             views
# date
# 2020-04-17      1
# 2020-04-18     23
# 2020-04-19     15
# 2020-04-21      3
# 2020-04-22      1
# 2020-04-23      5
# 2020-04-25      1
# 2020-04-26      8
# 2020-04-28      2
# 2020-04-29      4
# 2020-04-30      9
# 2020-05-01      3
# 2020-05-02      6
# 2020-05-03     19
# 2020-05-04      1
# 2020-05-05      1
# 2020-05-06      3
# 2020-05-07      2
# 2020-05-08     48
# 2020-05-09     19
# 2020-05-10    110
# 2020-05-11    200
# 2020-05-12     85
# 2020-05-13    102
# 2020-05-14    187
# 2020-05-15     29
# 2020-05-16      4
# 2020-05-17      9
# 2020-05-18     51
# 2020-05-19     11
# 2020-05-20     12
# 2020-05-21     11
# 2020-05-22      2

# %% [markdown]
# ## using Pandas method .plot(), create a graph

# %%
new_df.plot(fontsize=8,
            figsize=(15,8),
            title='Views per day',
            rot=90)
# Out:
# <AxesSubplot:title={'center':'Views per day'}, xlabel='date'>

# %% [markdown]
# ## close the connection to the database

# %%
connect.close()
